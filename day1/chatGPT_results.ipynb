# %% [markdown]
# ## Part 1

# %%
inputFile = 'input.txt'

# %%
with open(inputFile) as f:
    data = f.readlines()

# %% [markdown]
# ### Prompt

# %% [raw]
# solve this in python when the input is a list of strings ending with newline characters:
# lines = data.splitlines()
# calories = {}
# current_elf = None
#
# for line in lines:
#     if line == "":
#         # Blank line, switch to the next Elf
#         current_elf = None
#         continue
#
#     # Parse the number of Calories
#     calories_count = int(line)
#
#     if current_elf is None:
#         # Start a new entry for the Elf
#         current_elf = 1
#         calories[current_elf] = calories_count
#     else:
#         # Add the Calories to the existing entry for the Elf
#         calories[current_elf] += calories_count
#
# Find the Elf with the most Calories
# max_calories = max(calories.values(), key=lambda x: x)
#
# Print the result
# print(f"The Elf with the most calories is carrying {max_calories} Calories.")

# %%
lines = data
calories = {}
current_elf = None

for line in lines:
    if line == "\n":
        # Blank line, switch to the next Elf
        current_elf = None
        continue

    # Parse the number of Calories
    calories_count = int(line.strip())

    if current_elf is None:
        # Start a new entry for the Elf
        current_elf = 1
        calories[current_elf] = calories_count
    else:
        # Add the Calories to the existing entry for the Elf
        calories[current_elf] += calories_count

# Find the Elf with the most Calories
max_calories = max(calories.values(), key=lambda x: x)

# Print the result
print(f"The Elf with the most calories is carrying {max_calories} Calories.")
# Out:
# The Elf with the most calories is carrying 44617 Calories.

# %% [markdown]
# Incorrect answer, 44617 != 71300

# %% [markdown]
# ![Screen%20Shot%202022-12-06%20at%2012.33.22%20AM.png](attachment:Screen%20Shot%202022-12-06%20at%2012.33.22%20AM.png)

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Prompt

# %% [raw]
# solve te second part:
# By the time you calculate the answer to the Elves' question, they've already realized that the Elf carrying the most Calories of food might eventually run out of snacks.
#
# To avoid this unacceptable situation, the Elves would instead like to know the total Calories carried by the top three Elves carrying the most Calories. That way, even if one of those Elves runs out of snacks, they still have two backups.
#
# In the example above, the top three Elves are the fourth Elf (with 24000 Calories), then the third Elf (with 11000 Calories), then the fifth Elf (with 10000 Calories). The sum of the Calories carried by these three elves is 45000.
#
# Find the top three Elves carrying the most Calories. How many Calories are those Elves carrying in total?

# %%
lines = data
calories = {}
current_elf = None

for line in lines:
    if line == "\n":
        # Blank line, switch to the next Elf
        current_elf = None
        continue

    # Parse the number of Calories
    calories_count = int(line.strip())

    if current_elf is None:
        # Start a new entry for the Elf
        current_elf = 1
        calories[current_elf] = calories_count
    else:
        # Add the Calories to the existing entry for the Elf
        calories[current_elf] += calories_countm

# Sort the values in the calories dictionary by their frequency in descending order
sorted_calories = sorted(calories.values(), key=lambda x: x, reverse=True)

# Take the first three elements of the sorted list and sum them
top_three_calories = sorted_calories[0] + sorted_calories[1] + sorted_calories[2]

# Print the result
print(f"The top three Elves are carrying a total of {top_three_calories} Calories.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 26
#      23 sorted_calories = sorted(calories.values(), key=lambda x: x, reverse=True)
#      25 # Take the first three elements of the sorted list and sum them
# ---> 26 top_three_calories = sorted_calories[0] + sorted_calories[1] + sorted_calories[2]
#      28 # Print the result
#      29 print(f"The top three Elves are carrying a total of {top_three_calories} Calories.")
#
# IndexError: list index out of range

# %% [markdown]
# Also incorrect, cannot be interrupted...error
